# %%
# Import packages.
using JuMP, SCS, Mayday, Mosek

# %%
m = Model(solver=SCSSolver())

@variable(m, γ)

a = generator(:a)
b = generator(:b)
c = generator(:c)
x = generator(:x)
y = generator(:y)
v = defPolynomial(m, [:a, :b, :c, :x, :y], 5)
w = defPolynomial(m, [:a, :b, :c, :x, :y], 6)
r = defPolynomial(m, [:a, :b, :c, :x, :y], 7)
s = defPolynomial(m, [:a, :b, :c, :x, :y], 4)
p = a^8 + + 4b^8 - 3b^2*c^3 + c^8 + 2x^4 + 5y^4 - 2x^2 - 3y^2 - 3a^2
f1 = 4a + b^2 + 7c^3 + x^3 - 4y^2 - 1
f2 = a^2 - 4b^2 + c + x - 5y
f3 = a + b - c +2x + 14y
f4 = -3a^4 + b^3 - c^4 + x^2 - 12y^4

@objective(m, Max, γ)

addSoSConstraint(m, p - γ + v*f1 + w*f2 + r*f3 + s*f4)

m
# Out:
# Maximization problem with:
#  * 1287 linear constraints
#  * 1 semidefinite constraint
#  * 17509 variables
# Solver is SCS

# %%
solve(m)
# Out:
# WARN: m less than n, problem likely degenerate
# ----------------------------------------------------------------------------
# 	SCS v1.1.5 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 55915
# eps = 1.00e-004, alpha = 1.80, max_iters = 20000, normalize = 1, scale = 5.00
# Variables n = 17509, constraints m = 17163
# Cones:	primal zero / dual free vars: 9162
# 	sd vars: 8001, sd blks: 1
# Setup time: 2.02e-001s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0|1.#Je+000 1.#Je+000 -1.#Je+000 -1.#Je+000 1.#Je+000 1.#Je+000 8.46e-002
#    100|1.00e-002 4.47e-002 3.66e-004 2.05e+000 2.05e+000 0.00e+000 6.66e-001
#    200|1.88e-003 4.95e-003 6.27e-005 2.08e+000 2.08e+000 0.00e+000 1.22e+000
#    300|4.22e-004 9.95e-004 2.47e-006 2.08e+000 2.08e+000 0.00e+000 1.78e+000
#    400|2.51e-005 2.89e-004 4.07e-006 2.08e+000 2.08e+000 0.00e+000 2.31e+000
#    440|5.67e-005 8.11e-005 2.04e-006 2.08e+000 2.08e+000 0.00e+000 2.51e+000
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Total solve time: 2.51e+000s
# 	Lin-sys: nnz in L factor: 543602, avg solve time: 2.45e-003s
# 	Cones: avg projection time: 2.76e-003s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 4.5758e-016, dist(y, K*) = 1.1934e-009, s'y/m = 3.5851e-014
# |Ax + s - b|_2 / (1 + |b|_2) = 5.6678e-005
# |A'y + c|_2 / (1 + |c|_2) = 8.1070e-005
# |c'x + b'y| / (1 + |c'x| + |b'y|) = 2.0378e-006
# ----------------------------------------------------------------------------
# c'x = 2.0829, -b'y = 2.0829
# ============================================================================
# :Optimal

# %%
getvalue(γ)
# Out:
# -2.0829380158156185

# %%
m = Model(solver=MosekSolver())

@variable(m, γ)

a = generator(:a)
b = generator(:b)
c = generator(:c)
x = generator(:x)
y = generator(:y)
v = defPolynomial(m, [:a, :b, :c, :x, :y], 5)
w = defPolynomial(m, [:a, :b, :c, :x, :y], 6)
r = defPolynomial(m, [:a, :b, :c, :x, :y], 7)
s = defPolynomial(m, [:a, :b, :c, :x, :y], 4)
p = a^8 + + 4b^8 - 3b^2*c^3 + c^8 + 2x^4 + 5y^4 - 2x^2 - 3y^2 - 3a^2
f1 = 4a + b^2 + 7c^3 + x^3 - 4y^2 - 1
f2 = a^2 - 4b^2 + c + x - 5y
f3 = a + b - c +2x + 14y
f4 = -3a^4 + b^3 - c^4 + x^2 - 12y^4

@objective(m, Max, γ)

addSoSConstraint(m, p - γ + v*f1 + w*f2 + r*f3 + s*f4)

m
# Out:
# Maximization problem with:
#  * 1287 linear constraints
#  * 1 semidefinite constraint
#  * 17509 variables
# Solver is Mosek

# %%
solve(m)
# Out:
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 17163
#   Cones                  : 0
#   Scalar variables       : 17509
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Conic interior-point optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 8755
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.11
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.17
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 8408
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 8755              conic                  : 8755
# Optimizer  - Semi-definite variables: 1                 scalarized             : 8001
# Factor     - setup time             : 7.50              dense det. time        : 0.00
# Factor     - ML order time          : 3.36              GP order time          : 0.00
# Factor     - nonzeros before factor : 3.20e+007         after factor           : 3.30e+007
# Factor     - dense dim.             : 2                 flops                  : 1.75e+011
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+000 1.0e+000 1.0e+000 0.00e+000  0.000000000e+000  0.000000000e+000  1.0e+000 7.69
# 1   3.8e-001 3.8e-001 3.0e-001 -5.79e-001 8.932169656e-001  1.678176702e+000  3.8e-001 12.61
# 2   5.4e-002 5.4e-002 1.8e-001 7.83e-001  1.349413996e+000  1.361752596e+000  5.4e-002 18.52
# 3   8.1e-003 8.1e-003 1.1e-001 7.51e-001  1.932694116e+000  1.926687487e+000  8.1e-003 24.38
# 4   1.4e-003 1.4e-003 3.1e-002 1.25e+000  2.062221541e+000  2.062537812e+000  1.4e-003 29.30
# 5   7.5e-006 7.5e-006 2.5e-003 1.04e+000  2.082880390e+000  2.082880233e+000  7.5e-006 34.08
# 6   5.7e-010 5.6e-010 5.6e-010 1.00e+000  2.083006124e+000  2.083006123e+000  5.6e-010 39.13
# Interior-point optimizer terminated. Time: 39.16.
#
# Optimizer terminated. Time: 39.19
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 2.0830061237e+000   nrm: 5e+000   Viol.  con: 2e-009   var: 0e+000   barvar: 0e+000
#   Dual.    obj: 2.0830061233e+000   nrm: 1e+000   Viol.  con: 0e+000   var: 5e-010   barvar: 7e-010
# :Optimal

# %%
getvalue(γ)
# Out:
# -2.0830061237111552
