# %%
# Import packages.
using JuMP, SCS, Mayday, Mosek

# %%
m = Model(solver=SCSSolver())

@variable(m, γ)

x = generator(:x)
y = generator(:y)
z = generator(:z)
v = defPolynomial(m, [:x, :y, :z], 3)
p = 2x^6 - x^4 + 3y^2 + 2z^4 + z^6 - 3
f = x^3 - 4y + 10z - 1

@objective(m, Max, γ)

addSoSConstraint(m, p - γ + v*f)

m
# Out:
# Maximization problem with:
#  * 84 linear constraints
#  * 1 semidefinite constraint
#  * 421 variables
# Solver is SCS

# %%
solve(m)
# Out:
# ----------------------------------------------------------------------------
# 	SCS v1.1.5 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1261
# eps = 1.00e-004, alpha = 1.80, max_iters = 20000, normalize = 1, scale = 5.00
# Variables n = 421, constraints m = 484
# Cones:	primal zero / dual free vars: 274
# 	sd vars: 210, sd blks: 1
# Setup time: 4.80e-004s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0|1.#Je+000 1.#Je+000 -1.#Je+000 1.#Je+000 1.#Je+000 1.#Je+000 5.04e-004
#    100|1.99e-002 2.76e-002 4.74e-004 3.04e+000 3.04e+000 0.00e+000 4.73e-002
#    200|1.25e-003 2.49e-003 2.78e-005 3.04e+000 3.04e+000 0.00e+000 9.48e-002
#    300|1.26e-004 4.89e-004 4.72e-006 3.04e+000 3.04e+000 0.00e+000 1.37e-001
#    400|8.39e-005 2.60e-004 1.71e-006 3.04e+000 3.04e+000 0.00e+000 1.76e-001
#    500|7.41e-005 2.08e-004 6.82e-007 3.04e+000 3.04e+000 0.00e+000 2.17e-001
#    600|7.40e-005 1.72e-004 7.44e-007 3.04e+000 3.04e+000 0.00e+000 2.57e-001
#    700|7.37e-005 1.46e-004 6.97e-007 3.04e+000 3.04e+000 0.00e+000 2.87e-001
#    800|7.35e-005 1.24e-004 6.62e-007 3.04e+000 3.04e+000 0.00e+000 3.22e-001
#    900|7.33e-005 1.07e-004 6.34e-007 3.04e+000 3.04e+000 0.00e+000 3.63e-001
#    960|7.33e-005 9.83e-005 6.20e-007 3.04e+000 3.04e+000 0.00e+000 3.91e-001
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Total solve time: 3.91e-001s
# 	Lin-sys: nnz in L factor: 2583, avg solve time: 1.36e-005s
# 	Cones: avg projection time: 3.84e-004s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 8.7747e-010, dist(y, K*) = 2.1737e-009, s'y/m = 8.0805e-013
# |Ax + s - b|_2 / (1 + |b|_2) = 7.3261e-005
# |A'y + c|_2 / (1 + |c|_2) = 9.8283e-005
# |c'x + b'y| / (1 + |c'x| + |b'y|) = 6.1966e-007
# ----------------------------------------------------------------------------
# c'x = 3.0368, -b'y = 3.0368
# ============================================================================
# :Optimal

# %%
getvalue(γ)
# Out:
# -3.0368240084180367

# %%
m = Model(solver=MosekSolver())

@variable(m, γ)

x = generator(:x)
y = generator(:y)
z = generator(:z)
v = defPolynomial(m, [:x, :y, :z], 3)
p = 2x^6 - x^4 + 3y^2 + 2z^4 + z^6 - 3
f = x^3 - 4y + 10z - 1

@objective(m, Max, γ)

addSoSConstraint(m, p - γ + v*f)

m
# Out:
# Maximization problem with:
#  * 84 linear constraints
#  * 1 semidefinite constraint
#  * 421 variables
# Solver is Mosek

# %%
solve(m)
# Out:
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 484
#   Cones                  : 0
#   Scalar variables       : 421
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Conic interior-point optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 272
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 210
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 148               conic                  : 148
# Optimizer  - Semi-definite variables: 1                 scalarized             : 210
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.24e+004         after factor           : 2.24e+004
# Factor     - dense dim.             : 2                 flops                  : 3.31e+006
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   2.5e+000 1.0e+000 1.0e+000 0.00e+000  0.000000000e+000  0.000000000e+000  1.0e+000 0.00
# 1   4.0e-001 1.6e-001 6.3e-001 6.57e-003  3.421288632e+000  2.904070517e+000  1.6e-001 0.01
# 2   6.4e-002 2.6e-002 1.9e-001 2.12e+000  2.959809828e+000  2.965091874e+000  2.6e-002 0.01
# 3   8.4e-003 3.4e-003 1.2e-001 1.23e+000  3.031137001e+000  3.026334381e+000  3.4e-003 0.01
# 4   1.1e-003 4.5e-004 3.6e-002 1.05e+000  3.036674648e+000  3.036254869e+000  4.5e-004 0.01
# 5   2.1e-004 8.3e-005 1.6e-002 1.07e+000  3.036794271e+000  3.036708147e+000  8.3e-005 0.01
# 6   2.6e-005 1.0e-005 5.8e-003 9.62e-001  3.036927887e+000  3.036916188e+000  1.0e-005 0.01
# 7   5.1e-006 2.0e-006 2.7e-003 1.08e+000  3.036947446e+000  3.036945059e+000  2.0e-006 0.01
# 8   6.7e-007 2.7e-007 9.7e-004 9.51e-001  3.036951349e+000  3.036951032e+000  2.7e-007 0.03
# 9   1.2e-007 3.9e-008 4.1e-004 1.07e+000  3.036951854e+000  3.036951803e+000  4.0e-008 0.03
# 10  3.4e-008 2.1e-008 2.9e-004 9.95e-001  3.036951946e+000  3.036951920e+000  2.1e-008 0.03
# Interior-point optimizer terminated. Time: 0.03.
#
# Optimizer terminated. Time: 0.03
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 3.0369519459e+000   nrm: 3e+000   Viol.  con: 4e-008   var: 0e+000   barvar: 0e+000
#   Dual.    obj: 3.0369519203e+000   nrm: 6e+000   Viol.  con: 0e+000   var: 1e-008   barvar: 2e-008
# :Optimal

# %%
getvalue(γ)
# Out:
# -3.036951945930985
