# %%
# Import packages.
using JuMP, SCS, Mayday, Mosek

# %%
m = Model(solver=SCSSolver())

@variable(m, γ)

a = generator(:a)
x = generator(:x)
y = generator(:y)
z = generator(:z)
v = defPolynomial(m, [:a, :x, :y, :z], 1)
w = defPolynomial(m, [:a, :x, :y, :z], 2)
r = defPolynomial(m, [:a, :x, :y, :z], 3)
p = a^4 + 2x^4 + 5y^4 - 2x^2 - 3y^2 - 3a^2 - 2z^2 + z^4
f = 4a + x^3 - 4y^2 + 10z - 1
g = a^2 + x - 5y - 3z^2
h = a + 2x + 14y - 13z

@objective(m, Max, γ)

addSoSConstraint(m, p - γ + v*f + w*g + r*h)

m
# Out:
# WARNING: Array{T}(::Type{T}, m::Int, n::Int) is deprecated, use Array{T}(m, n) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64, ::Int64) at .\deprecated.jl:57
#  [3] MultiPoly.PolyUnion(::Array{MultiPoly.MPoly{Float64},1}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\polyunion.jl:9
#  [4] *(::MultiPoly.MPoly{Float64}, ::MultiPoly.MPoly{Float64}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:63
#  [5] _mapreduce(::Base.#identity, ::Base.#*, ::IndexLinear, ::Array{MultiPoly.MPoly{Float64},1}) at .\reduce.jl:273
#  [6] _collect(::Array{Array{Int64,1},1}, ::Base.Generator{Array{Array{Int64,1},1},Mayday.##1#3{Array{Symbol,1},Mayday.#monomial}}, ::Base.EltypeUnknown, ::Base.HasShape) at .\array.jl:454
#  [7] defPolynomial(::JuMP.Model, ::Array{Symbol,1}, ::Int64) at C:\Users\Michael\.julia\v0.6\Mayday\src\Mayday.jl:64
#  [8] include_string(::String, ::String) at .\loading.jl:515
#  [9] include_string(::Module, ::String, ::String) at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:71
#  [10] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\Michael\.julia\v0.6\IJulia\src\execute_request.jl:158
#  [11] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:385
#  [12] eventloop(::ZMQ.Socket) at C:\Users\Michael\.julia\v0.6\IJulia\src\eventloop.jl:8
#  [13] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[44], in expression starting on line 9
# WARNING: Array{T}(::Type{T}, m::Int, n::Int) is deprecated, use Array{T}(m, n) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64, ::Int64) at .\deprecated.jl:57
#  [3] MultiPoly.PolyUnion(::Array{MultiPoly.MPoly{Float64},1}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\polyunion.jl:9
#  [4] *(::MultiPoly.MPoly{Float64}, ::MultiPoly.MPoly{Float64}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:63
#  [5] _mapreduce(::Base.#identity, ::Base.#*, ::IndexLinear, ::Array{MultiPoly.MPoly{Float64},1}) at .\reduce.jl:273
#  [6] _collect(::Array{Array{Int64,1},1}, ::Base.Generator{Array{Array{Int64,1},1},Mayday.##1#3{Array{Symbol,1},Mayday.#monomial}}, ::Base.EltypeUnknown, ::Base.HasShape) at .\array.jl:454
#  [7] defPolynomial(::JuMP.Model, ::Array{Symbol,1}, ::Int64) at C:\Users\Michael\.julia\v0.6\Mayday\src\Mayday.jl:64
#  [8] include_string(::String, ::String) at .\loading.jl:515
#  [9] include_string(::Module, ::String, ::String) at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:71
#  [10] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\Michael\.julia\v0.6\IJulia\src\execute_request.jl:158
#  [11] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:385
#  [12] eventloop(::ZMQ.Socket) at C:\Users\Michael\.julia\v0.6\IJulia\src\eventloop.jl:8
#  [13] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[44], in expression starting on line 10
# WARNING: Array{T}(::Type{T}, m::Int, n::Int) is deprecated, use Array{T}(m, n) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64, ::Int64) at .\deprecated.jl:57
#  [3] MultiPoly.PolyUnion(::Array{MultiPoly.MPoly{Float64},1}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\polyunion.jl:9
#  [4] *(::MultiPoly.MPoly{Float64}, ::MultiPoly.MPoly{Float64}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:63
#  [5] _mapreduce(::Base.#identity, ::Base.#*, ::IndexLinear, ::Array{MultiPoly.MPoly{Float64},1}) at .\reduce.jl:273
#  [6] _collect(::Array{Array{Int64,1},1}, ::Base.Generator{Array{Array{Int64,1},1},Mayday.##1#3{Array{Symbol,1},Mayday.#monomial}}, ::Base.EltypeUnknown, ::Base.HasShape) at .\array.jl:454
#  [7] defPolynomial(::JuMP.Model, ::Array{Symbol,1}, ::Int64) at C:\Users\Michael\.julia\v0.6\Mayday\src\Mayday.jl:64
#  [8] include_string(::String, ::String) at .\loading.jl:515
#  [9] include_string(::Module, ::String, ::String) at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:71
#  [10] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\Michael\.julia\v0.6\IJulia\src\execute_request.jl:158
#  [11] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:385
#  [12] eventloop(::ZMQ.Socket) at C:\Users\Michael\.julia\v0.6\IJulia\src\eventloop.jl:8
#  [13] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[44], in expression starting on line 11
# WARNING: Array{T}(::Type{T}, m::Int, n::Int) is deprecated, use Array{T}(m, n) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64, ::Int64) at .\deprecated.jl:57
#  [3] MultiPoly.PolyUnion(::Array{MultiPoly.MPoly{Float64},1}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\polyunion.jl:9
#  [4] *(::MultiPoly.MPoly{Float64}, ::MultiPoly.MPoly{Float64}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:63
#  [5] ^(::MultiPoly.MPoly{Float64}, ::Int64) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:92 (repeats 2 times)
#  [6] literal_pow(::Base.#^, ::MultiPoly.MPoly{Float64}, ::Type{Val{4}}) at .\intfuncs.jl:205
#  [7] include_string(::String, ::String) at .\loading.jl:515
#  [8] include_string(::Module, ::String, ::String) at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:71
#  [9] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\Michael\.julia\v0.6\IJulia\src\execute_request.jl:158
#  [10] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:385
#  [11] eventloop(::ZMQ.Socket) at C:\Users\Michael\.julia\v0.6\IJulia\src\eventloop.jl:8
#  [12] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[44], in expression starting on line 12
# WARNING: Array{T}(::Type{T}, m::Int, n::Int) is deprecated, use Array{T}(m, n) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64, ::Int64) at .\deprecated.jl:57
#  [3] MultiPoly.PolyUnion(::Array{MultiPoly.MPoly{Float64},1}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\polyunion.jl:9
#  [4] *(::MultiPoly.MPoly{Float64}, ::MultiPoly.MPoly{Float64}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:63
#  [5] ^(::MultiPoly.MPoly{Float64}, ::Int64) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:92 (repeats 2 times)
#  [6] literal_pow(::Base.#^, ::MultiPoly.MPoly{Float64}, ::Type{Val{3}}) at .\intfuncs.jl:205
#  [7] include_string(::String, ::String) at .\loading.jl:515
#  [8] include_string(::Module, ::String, ::String) at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:71
#  [9] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\Michael\.julia\v0.6\IJulia\src\execute_request.jl:158
#  [10] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:385
#  [11] eventloop(::ZMQ.Socket) at C:\Users\Michael\.julia\v0.6\IJulia\src\eventloop.jl:8
#  [12] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[44], in expression starting on line 13
# WARNING: Array{T}(::Type{T}, m::Int, n::Int) is deprecated, use Array{T}(m, n) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64, ::Int64) at .\deprecated.jl:57
#  [3] MultiPoly.PolyUnion(::Array{MultiPoly.MPoly{Float64},1}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\polyunion.jl:9
#  [4] *(::MultiPoly.MPoly{Float64}, ::MultiPoly.MPoly{Float64}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:63
#  [5] ^(::MultiPoly.MPoly{Float64}, ::Int64) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:92
#  [6] literal_pow(::Base.#^, ::MultiPoly.MPoly{Float64}, ::Type{Val{2}}) at .\intfuncs.jl:205
#  [7] include_string(::String, ::String) at .\loading.jl:515
#  [8] include_string(::Module, ::String, ::String) at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:71
#  [9] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\Michael\.julia\v0.6\IJulia\src\execute_request.jl:158
#  [10] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:385
#  [11] eventloop(::ZMQ.Socket) at C:\Users\Michael\.julia\v0.6\IJulia\src\eventloop.jl:8
#  [12] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[44], in expression starting on line 14
# WARNING: Array{T}(::Type{T}, m::Int, n::Int) is deprecated, use Array{T}(m, n) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64, ::Int64) at .\deprecated.jl:57
#  [3] MultiPoly.PolyUnion(::Tuple{MultiPoly.MPoly{Float64},MultiPoly.MPoly{Float64},MultiPoly.MPoly{Float64}}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\polyunion.jl:9
#  [4] +(::MultiPoly.MPoly{Float64}, ::MultiPoly.MPoly{Float64}, ::MultiPoly.MPoly{Float64}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:2
#  [5] include_string(::String, ::String) at .\loading.jl:515
#  [6] include_string(::Module, ::String, ::String) at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:71
#  [7] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\Michael\.julia\v0.6\IJulia\src\execute_request.jl:158
#  [8] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:385
#  [9] eventloop(::ZMQ.Socket) at C:\Users\Michael\.julia\v0.6\IJulia\src\eventloop.jl:8
#  [10] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[44], in expression starting on line 15
# WARNING: Array{T}(::Type{T}, m::Int, n::Int) is deprecated, use Array{T}(m, n) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64, ::Int64) at .\deprecated.jl:57
#  [3] MultiPoly.PolyUnion(::Array{MultiPoly.MPoly{JuMP.GenericAffExpr{Float64,JuMP.Variable}},1}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\polyunion.jl:9
#  [4] *(::MultiPoly.MPoly{JuMP.GenericAffExpr{Float64,JuMP.Variable}}, ::MultiPoly.MPoly{Float64}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:63
#  [5] include_string(::String, ::String) at .\loading.jl:515
#  [6] include_string(::Module, ::String, ::String) at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:71
#  [7] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\Michael\.julia\v0.6\IJulia\src\execute_request.jl:158
#  [8] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:385
#  [9] eventloop(::ZMQ.Socket) at C:\Users\Michael\.julia\v0.6\IJulia\src\eventloop.jl:8
#  [10] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[44], in expression starting on line 19
# Maximization problem with:
#  * 70 linear constraints
#  * 1 semidefinite constraint
#  * 281 variables
# Solver is SCS

# %%
solve(m)
# Out:
# ----------------------------------------------------------------------------
# 	SCS v1.1.5 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 886
# eps = 1.00e-004, alpha = 1.80, max_iters = 20000, normalize = 1, scale = 5.00
# Variables n = 281, constraints m = 295
# Cones:	primal zero / dual free vars: 175
# 	sd vars: 120, sd blks: 1
# Setup time: 6.15e-004s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0|1.#Je+000 1.#Je+000 -1.#Je+000 -1.#Je+000 1.#Je+000 1.#Je+000 1.42e-003
#    100|5.80e-002 1.34e-001 2.13e-004 1.87e+000 1.87e+000 3.44e-017 5.08e-002
#    200|5.61e-002 7.81e-002 9.57e-004 2.25e+000 2.25e+000 3.94e-017 9.54e-002
#    300|3.15e-002 4.58e-002 2.93e-004 2.27e+000 2.27e+000 3.99e-017 1.37e-001
#    400|2.35e-002 1.81e-002 1.46e-004 2.25e+000 2.25e+000 4.00e-017 1.77e-001
#    500|1.27e-002 2.23e-002 3.19e-005 2.27e+000 2.27e+000 4.03e-017 2.23e-001
#    600|7.08e-003 1.79e-002 1.38e-004 2.29e+000 2.29e+000 4.05e-017 2.69e-001
#    700|5.86e-003 1.10e-002 5.12e-005 2.29e+000 2.29e+000 4.04e-017 3.08e-001
#    800|6.34e-003 4.28e-003 2.49e-006 2.29e+000 2.29e+000 4.04e-017 3.48e-001
#    900|1.86e-003 7.19e-003 1.70e-006 2.29e+000 2.29e+000 4.04e-017 3.92e-001
#   1000|2.94e-003 3.40e-003 4.37e-006 2.29e+000 2.29e+000 4.04e-017 4.36e-001
#   1100|1.36e-003 3.28e-003 8.97e-006 2.29e+000 2.29e+000 4.04e-017 4.78e-001
#   1200|1.73e-003 1.18e-003 1.77e-006 2.28e+000 2.28e+000 4.04e-017 5.15e-001
#   1300|5.01e-004 1.94e-003 9.44e-006 2.29e+000 2.29e+000 4.04e-017 5.55e-001
#   1400|9.22e-004 7.81e-004 3.02e-006 2.29e+000 2.29e+000 4.04e-017 5.99e-001
#   1500|3.57e-004 1.07e-003 4.40e-006 2.29e+000 2.29e+000 4.04e-017 6.44e-001
#   1600|5.20e-004 5.27e-004 3.08e-006 2.29e+000 2.29e+000 4.04e-017 6.79e-001
#   1700|2.32e-004 5.98e-004 7.55e-007 2.29e+000 2.29e+000 4.04e-017 7.17e-001
#   1800|3.13e-004 3.05e-004 6.50e-007 2.29e+000 2.29e+000 4.04e-017 7.57e-001
#   1900|1.29e-004 3.61e-004 6.19e-007 2.29e+000 2.29e+000 4.04e-017 7.95e-001
#   2000|1.84e-004 1.85e-004 5.28e-008 2.29e+000 2.29e+000 4.04e-017 8.37e-001
#   2100|8.13e-005 2.07e-004 6.43e-007 2.29e+000 2.29e+000 4.04e-017 8.79e-001
#   2200|1.07e-004 1.14e-004 6.24e-008 2.29e+000 2.29e+000 4.04e-017 9.21e-001
#   2300|5.10e-005 1.20e-004 4.59e-007 2.29e+000 2.29e+000 4.04e-017 9.73e-001
#   2320|9.00e-005 1.94e-005 3.21e-007 2.29e+000 2.29e+000 4.04e-017 9.82e-001
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Total solve time: 9.82e-001s
# 	Lin-sys: nnz in L factor: 2255, avg solve time: 1.97e-005s
# 	Cones: avg projection time: 3.93e-004s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 6.6167e-010, dist(y, K*) = 1.7462e-009, s'y/m = -5.1396e-012
# |Ax + s - b|_2 / (1 + |b|_2) = 9.0005e-005
# |A'y + c|_2 / (1 + |c|_2) = 1.9429e-005
# |c'x + b'y| / (1 + |c'x| + |b'y|) = 3.2078e-007
# ----------------------------------------------------------------------------
# c'x = 2.2856, -b'y = 2.2856
# ============================================================================
# :Optimal

# %%
getvalue(γ)
# Out:
# -2.285588363698522

# %%
m = Model(solver=MosekSolver())

@variable(m, γ)

a = generator(:a)
x = generator(:x)
y = generator(:y)
z = generator(:z)
v = defPolynomial(m, [:a, :x, :y, :z], 1)
w = defPolynomial(m, [:a, :x, :y, :z], 2)
r = defPolynomial(m, [:a, :x, :y, :z], 3)
p = a^4 + 2x^4 + 5y^4 - 2x^2 - 3y^2 - 3a^2 - 2z^2 + z^4
f = 4a + x^3 - 4y^2 + 10z - 1
g = a^2 + x - 5y - 3z^2
h = a + 2x + 14y - 13z

@objective(m, Max, γ)

addSoSConstraint(m, p - γ + v*f + w*g + r*h)

m
# Out:
# WARNING: Array{T}(::Type{T}, m::Int, n::Int) is deprecated, use Array{T}(m, n) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64, ::Int64) at .\deprecated.jl:57
#  [3] MultiPoly.PolyUnion(::Array{MultiPoly.MPoly{Float64},1}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\polyunion.jl:9
#  [4] *(::MultiPoly.MPoly{Float64}, ::MultiPoly.MPoly{Float64}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:63
#  [5] _mapreduce(::Base.#identity, ::Base.#*, ::IndexLinear, ::Array{MultiPoly.MPoly{Float64},1}) at .\reduce.jl:273
#  [6] _collect(::Array{Array{Int64,1},1}, ::Base.Generator{Array{Array{Int64,1},1},Mayday.##1#3{Array{Symbol,1},Mayday.#monomial}}, ::Base.EltypeUnknown, ::Base.HasShape) at .\array.jl:454
#  [7] defPolynomial(::JuMP.Model, ::Array{Symbol,1}, ::Int64) at C:\Users\Michael\.julia\v0.6\Mayday\src\Mayday.jl:64
#  [8] include_string(::String, ::String) at .\loading.jl:515
#  [9] include_string(::Module, ::String, ::String) at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:71
#  [10] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\Michael\.julia\v0.6\IJulia\src\execute_request.jl:158
#  [11] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:385
#  [12] eventloop(::ZMQ.Socket) at C:\Users\Michael\.julia\v0.6\IJulia\src\eventloop.jl:8
#  [13] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[47], in expression starting on line 9
# WARNING: Array{T}(::Type{T}, m::Int, n::Int) is deprecated, use Array{T}(m, n) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64, ::Int64) at .\deprecated.jl:57
#  [3] MultiPoly.PolyUnion(::Array{MultiPoly.MPoly{Float64},1}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\polyunion.jl:9
#  [4] *(::MultiPoly.MPoly{Float64}, ::MultiPoly.MPoly{Float64}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:63
#  [5] _mapreduce(::Base.#identity, ::Base.#*, ::IndexLinear, ::Array{MultiPoly.MPoly{Float64},1}) at .\reduce.jl:273
#  [6] _collect(::Array{Array{Int64,1},1}, ::Base.Generator{Array{Array{Int64,1},1},Mayday.##1#3{Array{Symbol,1},Mayday.#monomial}}, ::Base.EltypeUnknown, ::Base.HasShape) at .\array.jl:454
#  [7] defPolynomial(::JuMP.Model, ::Array{Symbol,1}, ::Int64) at C:\Users\Michael\.julia\v0.6\Mayday\src\Mayday.jl:64
#  [8] include_string(::String, ::String) at .\loading.jl:515
#  [9] include_string(::Module, ::String, ::String) at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:71
#  [10] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\Michael\.julia\v0.6\IJulia\src\execute_request.jl:158
#  [11] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:385
#  [12] eventloop(::ZMQ.Socket) at C:\Users\Michael\.julia\v0.6\IJulia\src\eventloop.jl:8
#  [13] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[47], in expression starting on line 10
# WARNING: Array{T}(::Type{T}, m::Int, n::Int) is deprecated, use Array{T}(m, n) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64, ::Int64) at .\deprecated.jl:57
#  [3] MultiPoly.PolyUnion(::Array{MultiPoly.MPoly{Float64},1}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\polyunion.jl:9
#  [4] *(::MultiPoly.MPoly{Float64}, ::MultiPoly.MPoly{Float64}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:63
#  [5] _mapreduce(::Base.#identity, ::Base.#*, ::IndexLinear, ::Array{MultiPoly.MPoly{Float64},1}) at .\reduce.jl:273
#  [6] _collect(::Array{Array{Int64,1},1}, ::Base.Generator{Array{Array{Int64,1},1},Mayday.##1#3{Array{Symbol,1},Mayday.#monomial}}, ::Base.EltypeUnknown, ::Base.HasShape) at .\array.jl:454
#  [7] defPolynomial(::JuMP.Model, ::Array{Symbol,1}, ::Int64) at C:\Users\Michael\.julia\v0.6\Mayday\src\Mayday.jl:64
#  [8] include_string(::String, ::String) at .\loading.jl:515
#  [9] include_string(::Module, ::String, ::String) at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:71
#  [10] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\Michael\.julia\v0.6\IJulia\src\execute_request.jl:158
#  [11] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:385
#  [12] eventloop(::ZMQ.Socket) at C:\Users\Michael\.julia\v0.6\IJulia\src\eventloop.jl:8
#  [13] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[47], in expression starting on line 11
# WARNING: Array{T}(::Type{T}, m::Int, n::Int) is deprecated, use Array{T}(m, n) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64, ::Int64) at .\deprecated.jl:57
#  [3] MultiPoly.PolyUnion(::Array{MultiPoly.MPoly{Float64},1}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\polyunion.jl:9
#  [4] *(::MultiPoly.MPoly{Float64}, ::MultiPoly.MPoly{Float64}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:63
#  [5] ^(::MultiPoly.MPoly{Float64}, ::Int64) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:92 (repeats 2 times)
#  [6] literal_pow(::Base.#^, ::MultiPoly.MPoly{Float64}, ::Type{Val{4}}) at .\intfuncs.jl:205
#  [7] include_string(::String, ::String) at .\loading.jl:515
#  [8] include_string(::Module, ::String, ::String) at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:71
#  [9] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\Michael\.julia\v0.6\IJulia\src\execute_request.jl:158
#  [10] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:385
#  [11] eventloop(::ZMQ.Socket) at C:\Users\Michael\.julia\v0.6\IJulia\src\eventloop.jl:8
#  [12] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[47], in expression starting on line 12
# WARNING: Array{T}(::Type{T}, m::Int, n::Int) is deprecated, use Array{T}(m, n) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64, ::Int64) at .\deprecated.jl:57
#  [3] MultiPoly.PolyUnion(::Array{MultiPoly.MPoly{Float64},1}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\polyunion.jl:9
#  [4] *(::MultiPoly.MPoly{Float64}, ::MultiPoly.MPoly{Float64}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:63
#  [5] ^(::MultiPoly.MPoly{Float64}, ::Int64) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:92 (repeats 2 times)
#  [6] literal_pow(::Base.#^, ::MultiPoly.MPoly{Float64}, ::Type{Val{3}}) at .\intfuncs.jl:205
#  [7] include_string(::String, ::String) at .\loading.jl:515
#  [8] include_string(::Module, ::String, ::String) at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:71
#  [9] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\Michael\.julia\v0.6\IJulia\src\execute_request.jl:158
#  [10] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:385
#  [11] eventloop(::ZMQ.Socket) at C:\Users\Michael\.julia\v0.6\IJulia\src\eventloop.jl:8
#  [12] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[47], in expression starting on line 13
# WARNING: Array{T}(::Type{T}, m::Int, n::Int) is deprecated, use Array{T}(m, n) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64, ::Int64) at .\deprecated.jl:57
#  [3] MultiPoly.PolyUnion(::Array{MultiPoly.MPoly{Float64},1}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\polyunion.jl:9
#  [4] *(::MultiPoly.MPoly{Float64}, ::MultiPoly.MPoly{Float64}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:63
#  [5] ^(::MultiPoly.MPoly{Float64}, ::Int64) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:92
#  [6] literal_pow(::Base.#^, ::MultiPoly.MPoly{Float64}, ::Type{Val{2}}) at .\intfuncs.jl:205
#  [7] include_string(::String, ::String) at .\loading.jl:515
#  [8] include_string(::Module, ::String, ::String) at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:71
#  [9] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\Michael\.julia\v0.6\IJulia\src\execute_request.jl:158
#  [10] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:385
#  [11] eventloop(::ZMQ.Socket) at C:\Users\Michael\.julia\v0.6\IJulia\src\eventloop.jl:8
#  [12] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[47], in expression starting on line 14
# WARNING: Array{T}(::Type{T}, m::Int, n::Int) is deprecated, use Array{T}(m, n) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64, ::Int64) at .\deprecated.jl:57
#  [3] MultiPoly.PolyUnion(::Tuple{MultiPoly.MPoly{Float64},MultiPoly.MPoly{Float64},MultiPoly.MPoly{Float64}}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\polyunion.jl:9
#  [4] +(::MultiPoly.MPoly{Float64}, ::MultiPoly.MPoly{Float64}, ::MultiPoly.MPoly{Float64}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:2
#  [5] include_string(::String, ::String) at .\loading.jl:515
#  [6] include_string(::Module, ::String, ::String) at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:71
#  [7] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\Michael\.julia\v0.6\IJulia\src\execute_request.jl:158
#  [8] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:385
#  [9] eventloop(::ZMQ.Socket) at C:\Users\Michael\.julia\v0.6\IJulia\src\eventloop.jl:8
#  [10] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[47], in expression starting on line 15
# WARNING: Array{T}(::Type{T}, m::Int, n::Int) is deprecated, use Array{T}(m, n) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at .\deprecated.jl:70
#  [2] Array(::Type{Int64}, ::Int64, ::Int64) at .\deprecated.jl:57
#  [3] MultiPoly.PolyUnion(::Array{MultiPoly.MPoly{JuMP.GenericAffExpr{Float64,JuMP.Variable}},1}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\polyunion.jl:9
#  [4] *(::MultiPoly.MPoly{JuMP.GenericAffExpr{Float64,JuMP.Variable}}, ::MultiPoly.MPoly{Float64}) at C:\Users\Michael\.julia\v0.6\MultiPoly\src\mpolyarithmetic.jl:63
#  [5] include_string(::String, ::String) at .\loading.jl:515
#  [6] include_string(::Module, ::String, ::String) at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:71
#  [7] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\Michael\.julia\v0.6\IJulia\src\execute_request.jl:158
#  [8] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at C:\Users\Michael\.julia\v0.6\Compat\src\Compat.jl:385
#  [9] eventloop(::ZMQ.Socket) at C:\Users\Michael\.julia\v0.6\IJulia\src\eventloop.jl:8
#  [10] (::IJulia.##14#17)() at .\task.jl:335
# while loading In[47], in expression starting on line 19
# Maximization problem with:
#  * 70 linear constraints
#  * 1 semidefinite constraint
#  * 281 variables
# Solver is Mosek

# %%
solve(m)
# Out:
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 295
#   Cones                  : 0
#   Scalar variables       : 281
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Conic interior-point optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 175
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 120
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 107               conic                  : 107
# Optimizer  - Semi-definite variables: 1                 scalarized             : 120
# Factor     - setup time             : 0.02              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 7260              after factor           : 7260
# Factor     - dense dim.             : 0                 flops                  : 6.51e+005
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+000 1.0e+000 1.0e+000 0.00e+000  0.000000000e+000  0.000000000e+000  1.0e+000 0.02
# 1   2.2e-001 2.2e-001 2.3e-001 -2.62e-001 1.055982477e+000  1.545355469e+000  2.2e-001 0.02
# 2   3.9e-002 3.9e-002 1.1e-001 8.27e-001  1.780009795e+000  1.830851528e+000  3.9e-002 0.02
# 3   4.9e-003 4.9e-003 2.6e-002 7.14e-001  2.159525555e+000  2.182391138e+000  4.9e-003 0.02
# 4   3.4e-003 3.4e-003 2.1e-002 7.90e-001  2.200177619e+000  2.217461466e+000  3.4e-003 0.02
# 5   1.8e-004 1.8e-004 7.3e-003 1.01e+000  2.281672799e+000  2.281840358e+000  1.8e-004 0.02
# 6   3.4e-006 3.4e-006 1.0e-003 1.01e+000  2.285469454e+000  2.285471493e+000  3.4e-006 0.02
# 7   1.9e-008 1.9e-008 7.9e-005 1.00e+000  2.285548342e+000  2.285548352e+000  1.9e-008 0.02
# 8   4.0e-010 7.7e-010 1.1e-005 1.00e+000  2.285548763e+000  2.285548763e+000  4.0e-010 0.02
# Interior-point optimizer terminated. Time: 0.02.
#
# Optimizer terminated. Time: 0.02
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 2.2855487630e+000   nrm: 5e+000   Viol.  con: 4e-009   var: 0e+000   barvar: 0e+000
#   Dual.    obj: 2.2855487632e+000   nrm: 2e+000   Viol.  con: 0e+000   var: 6e-010   barvar: 2e-009
# :Optimal

# %%
getvalue(γ)
# Out:
# -2.2855487629755125
